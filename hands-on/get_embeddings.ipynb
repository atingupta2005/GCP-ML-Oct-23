# %%
#!sudo apt install -y tesseract-ocr
#!pip install pytesseract
#!pip install opencv-python
#!pip install thefuzz

# %%
import pytesseract
import cv2
from pytesseract import*
import argparse 
import os
import clip
import torch
from torch.utils.data import Dataset, DataLoader
import PIL
import pickle
from tqdm import tqdm
from thefuzz import fuzz
import pandas as pd

# %%
class Images(Dataset):
        """Images dataset"""
        
        def __init__(self, image_list, transform):
            """
            Args:
                image_list: List of image paths.
                transform : Transform to be applied on a sample.
            """
            self.image_list = image_list
            self.transform = transform
        
        def __len__(self):
            return len(self.image_list)
        
        def __getitem__(self, idx):
            image_path = self.image_list[idx]
            print("image_path: ", image_path)
            image = PIL.Image.open(image_path)
            image = self.transform(image)
            data = {'image':image, 
                    'img_path': image_path}
            return data

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load('ViT-B/32', device, jit=False)
print(f'Device used: {device}')

folder_path = 'images/'
image_list = [folder_path + file for file in os.listdir(folder_path)]
# Out:
# Device used: cpu

# %%
print('Attempting to open images...')
cleaned_image_list = []
for image_path in image_list:
    try:
        print("image_path: ", image_path)
        PIL.Image.open(image_path)
        cleaned_image_list.append(image_path)
    except:
        print(f"Failed for {image_path}")

print(f"There are {len(cleaned_image_list)} images that can be processed")    
dataset = Images(cleaned_image_list,preprocess)

dataloader = DataLoader(dataset, 
                        batch_size=256,
                        shuffle=True)
# Out:
# Attempting to open images...
# image_path:  images/Test250.jpg
# image_path:  images/Test230.jpg
# image_path:  images/Test3159.jpg
# image_path:  images/Test2870.jpg
# image_path:  images/Test1717.jpg
# image_path:  images/Test482.jpg
# image_path:  images/.ipynb_checkpoints
# Failed for images/.ipynb_checkpoints
# image_path:  images/Test1620.jpg
# image_path:  images/Test1856.jpg
# image_path:  images/Test581.jpg
# image_path:  images/Test1902.jpg
# image_path:  images/Test129.jpg
# image_path:  images/Test2371.jpg
# image_path:  images/Test519.jpg
# image_path:  images/Test946.jpg
# image_path:  images/17.jpg
# image_path:  images/Test133.jpg
# image_path:  images/Test1889.jpg
# image_path:  images/Test2068.jpg
# image_path:  images/Test2590.jpg
# image_path:  images/Test1359.jpg
# image_path:  images/Test109.jpg
# image_path:  images/0.jpg
# image_path:  images/Test677.jpg
# image_path:  images/Test1785.jpg
# image_path:  images/Test1788.jpg
# image_path:  images/Test172.jpg
# image_path:  images/Test188.jpg
# image_path:  images/Test206.jpg
# image_path:  images/Test3525.jpg
# image_path:  images/Test1353.jpg
# image_path:  images/Test141.jpg
# image_path:  images/Test3985.jpg
# image_path:  images/Test3798.jpg
# image_path:  images/Test221.jpg
# image_path:  images/14.jpg
# image_path:  images/Test1022.jpg
# image_path:  images/Test1884.jpg
# image_path:  images/Test240.jpg
# image_path:  images/Test187.jpg
# image_path:  images/Test522.jpg
# image_path:  images/Test3863.jpg
# image_path:  images/Test211.jpg
# image_path:  images/Test957.jpg
# image_path:  images/16.jpg
# image_path:  images/Test2977.jpg
# image_path:  images/Test143.jpg
# image_path:  images/Test227.jpg
# image_path:  images/Test149.jpg
# image_path:  images/Test2309.jpg
# image_path:  images/Test516.jpg
# image_path:  images/6.JPG
# image_path:  images/Test135.jpg
# image_path:  images/Test422.jpg
# image_path:  images/Test216.jpg
# image_path:  images/Test2007.jpg
# image_path:  images/Test212.jpg
# image_path:  images/Test3706.jpg
# image_path:  images/Test861.jpg
# image_path:  images/Test168.jpg
# image_path:  images/Test400.jpg
# image_path:  images/Test3566.jpg
# image_path:  images/8.jpg
# image_path:  images/Test803.jpg
# image_path:  images/Test606.jpg
# image_path:  images/Test1934.jpg
# image_path:  images/Test833.jpg
# image_path:  images/Test1279.jpg
# image_path:  images/Test3864.jpg
# image_path:  images/Test941.jpg
# image_path:  images/Test213.jpg
# image_path:  images/Test1743.jpg
# image_path:  images/Test2616.jpg
# image_path:  images/Test812.jpg
# image_path:  images/Test660.jpg
# image_path:  images/Test1923.jpg
# image_path:  images/Test644.jpg
# image_path:  images/Test587.jpg
# image_path:  images/Test166.jpg
# image_path:  images/Test1724.jpg
# image_path:  images/Test236.jpg
# image_path:  images/Test449.jpg
# image_path:  images/Test249.jpg
# image_path:  images/Test979.jpg
# image_path:  images/Test3130.jpg
# image_path:  images/Test835.jpg
# image_path:  images/Test242.jpg
# image_path:  images/Test3789.jpg
# image_path:  images/Test2650.jpg
# image_path:  images/Test225.jpg
# image_path:  images/Test2049.jpg
# image_path:  images/2.jpg
# image_path:  images/Test396.jpg
# image_path:  images/Test2792.jpg
# image_path:  images/Test108.jpg
# image_path:  images/Test160.jpg
# image_path:  images/Test837.jpg
# image_path:  images/Test3749.jpg
# image_path:  images/Test397.jpg
# image_path:  images/Test523.jpg
# image_path:  images/Test173.jpg
# image_path:  images/Test232.jpg
# image_path:  images/Test661.jpg
# image_path:  images/Test209.jpg
# image_path:  images/Test3265.jpg
# image_path:  images/Test1776.jpg
# image_path:  images/Test191.jpg
# image_path:  images/Test378.jpg
# image_path:  images/Test2114.jpg
# image_path:  images/Test1803.jpg
# image_path:  images/Test751.jpg
# image_path:  images/Test929.jpg
# image_path:  images/Test117.jpg
# image_path:  images/1.jpg
# image_path:  images/Test372.jpg
# image_path:  images/Test1290.jpg
# image_path:  images/Test3750.jpg
# image_path:  images/Test859.jpg
# image_path:  images/Test3277.jpg
# image_path:  images/13.jpg
# image_path:  images/Test3246.jpg
# image_path:  images/Test945.jpg
# image_path:  images/Test244.jpg
# image_path:  images/Test824.jpg
# image_path:  images/Test2962.jpg
# image_path:  images/Test624.jpg
# image_path:  images/Test912.jpg
# image_path:  images/Test1229.jpg
# image_path:  images/Test233.jpg
# image_path:  images/Test890.jpg
# image_path:  images/Test198.jpg
# image_path:  images/Test715.jpg
# image_path:  images/Test884.jpg
# image_path:  images/Test3975.jpg
# image_path:  images/Test937.jpg
# image_path:  images/Test1837.jpg
# image_path:  images/Test238.jpg
# image_path:  images/Test1818.jpg
# image_path:  images/Test545.jpg
# image_path:  images/Test1615.jpg
# image_path:  images/Test1872.jpg
# image_path:  images/Test668.jpg
# image_path:  images/15.jpg
# image_path:  images/Test778.jpg
# image_path:  images/Test811.jpg
# image_path:  images/Test3827.jpg
# image_path:  images/Test374.jpg
# image_path:  images/Test2411.jpg
# image_path:  images/Test234.jpg
# image_path:  images/12.jpg
# image_path:  images/Test122.jpg
# image_path:  images/Test1767.jpg
# image_path:  images/Test3512.jpg
# image_path:  images/Test1240.jpg
# image_path:  images/Test2434.jpg
# image_path:  images/4.jpg
# image_path:  images/Test3934.jpg
# image_path:  images/Test183.jpg
# image_path:  images/Test2743.jpg
# image_path:  images/Test192.jpg
# image_path:  images/Test164.jpg
# image_path:  images/3.jpg
# image_path:  images/Test527.jpg
# image_path:  images/Test1071.jpg
# image_path:  images/Test1992.jpg
# image_path:  images/Test245.jpg
# image_path:  images/Test180.jpg
# image_path:  images/Test181.jpg
# image_path:  images/Test2648.jpg
# image_path:  images/Test100.jpg
# image_path:  images/Test239.jpg
# image_path:  images/Test1885.jpg
# image_path:  images/Test154.jpg
# image_path:  images/Test526.jpg
# image_path:  images/Test440.jpg
# image_path:  images/Test1161.jpg
# image_path:  images/Test789.jpg
# image_path:  images/Test417.jpg
# image_path:  images/Test114.jpg
# image_path:  images/Test2791.jpg
# image_path:  images/Test490.jpg
# image_path:  images/Test3177.jpg
# image_path:  images/Test204.jpg
# image_path:  images/Test136.jpg
# image_path:  images/Test1199.jpg
# image_path:  images/Test536.jpg
# image_path:  images/Test151.jpg
# image_path:  images/Test145.jpg
# image_path:  images/Test3024.jpg
# image_path:  images/19.jpg
# image_path:  images/Test126.jpg
# image_path:  images/Test161.jpg
# image_path:  images/Test1634.jpg
# image_path:  images/7.jpg
# image_path:  images/Test3625.jpg
# image_path:  images/Test105.jpg
# image_path:  images/Test243.jpg
# image_path:  images/Test119.jpg
# image_path:  images/18.jpg
# image_path:  images/Test134.jpg
# image_path:  images/Test843.jpg
# image_path:  images/Test903.jpg
# image_path:  images/Test152.jpg
# image_path:  images/Test498.jpg
# image_path:  images/Test132.jpg
# image_path:  images/Test194.jpg
# image_path:  images/Test942.jpg
# image_path:  images/Test2235.jpg
# image_path:  images/Test834.jpg
# image_path:  images/Test2455.jpg
# image_path:  images/Test3030.jpg
# image_path:  images/11.jpg
# image_path:  images/Test3893.jpg
# image_path:  images/Test2280.jpg
# image_path:  images/Test2959.jpg
# image_path:  images/Test128.jpg
# image_path:  images/5.jpg
# image_path:  images/Test158.jpg
# image_path:  images/Test144.jpg
# image_path:  images/Test218.jpg
# image_path:  images/Test993.jpg
# image_path:  images/Test3118.jpg
# image_path:  images/Test761.jpg
# image_path:  images/Test614.jpg
# image_path:  images/9.jpg
# image_path:  images/Test2209.jpg
# image_path:  images/Test1644.jpg
# image_path:  images/Test165.jpg
# image_path:  images/Test1954.jpg
# image_path:  images/Test1122.jpg
# image_path:  images/Test228.jpg
# image_path:  images/Test162.jpg
# image_path:  images/Test113.jpg
# image_path:  images/Test757.jpg
# image_path:  images/Test3360.jpg
# image_path:  images/Test3294.jpg
# image_path:  images/Test2424.jpg
# image_path:  images/Test1012.jpg
# image_path:  images/Test231.jpg
# image_path:  images/Test533.jpg
# image_path:  images/Test612.jpg
# image_path:  images/Test179.jpg
# image_path:  images/Test360.jpg
# image_path:  images/Test107.jpg
# image_path:  images/Test125.jpg
# image_path:  images/Test665.jpg
# image_path:  images/Test779.jpg
# image_path:  images/Test103.jpg
# image_path:  images/Test1271.jpg
# image_path:  images/Test760.jpg
# image_path:  images/Test579.jpg
# image_path:  images/Test1001.jpg
# image_path:  images/Test176.jpg
# image_path:  images/Test353.jpg
# image_path:  images/10.jpg
# image_path:  images/Test131.jpg
# image_path:  images/Test140.jpg
# image_path:  images/Test489.jpg
# image_path:  images/Test201.jpg
# image_path:  images/Test237.jpg
# There are 259 images that can be processed

# %%
print("Processing images...")
image_paths = []
embeddings = []
# Out:
# Processing images...

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
ktr = 1
for data in tqdm(dataloader):
    print("Ktr: ", ktr)
    with torch.no_grad():
        try:
            X = data['image'].to(device)
            image_embedding = model.encode_image(X)
            img_path = data['img_path']
            image_paths.extend(img_path)
            embeddings.extend([torch.Tensor(x).unsqueeze(0).cpu() for x in image_embedding.tolist()])
            ktr = ktr + 1
        except:
            pass
            print("Error")
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# image_path:  images/Test677.jpg
# image_path:  images/Test149.jpg
# image_path:  images/19.jpg
# image_path:  images/8.jpg
# image_path:  images/Test2007.jpg
# image_path:  images/Test400.jpg
# image_path:  images/Test489.jpg
# image_path:  images/Test162.jpg
# image_path:  images/Test3749.jpg
# image_path:  images/Test176.jpg
# image_path:  images/Test160.jpg
# image_path:  images/Test221.jpg
# image_path:  images/Test778.jpg
# image_path:  images/Test3789.jpg
# image_path:  images/Test126.jpg
# image_path:  images/Test168.jpg
# image_path:  images/Test3265.jpg
# image_path:  images/Test3118.jpg
# image_path:  images/Test929.jpg
# image_path:  images/Test228.jpg
# image_path:  images/Test803.jpg
# image_path:  images/Test225.jpg
# image_path:  images/Test2616.jpg
# image_path:  images/Test3985.jpg
# image_path:  images/Test103.jpg
# image_path:  images/Test665.jpg
# image_path:  images/Test1240.jpg
# image_path:  images/Test624.jpg
# image_path:  images/Test3024.jpg
# image_path:  images/Test2959.jpg
# image_path:  images/Test837.jpg
# image_path:  images/Test165.jpg
# image_path:  images/Test236.jpg
# image_path:  images/Test945.jpg
# image_path:  images/Test125.jpg
# image_path:  images/Test2962.jpg
# image_path:  images/Test1837.jpg
# image_path:  images/Test378.jpg
# image_path:  images/Test1785.jpg
# image_path:  images/Test523.jpg
# image_path:  images/Test527.jpg
# image_path:  images/Test143.jpg
# image_path:  images/Test2870.jpg
# image_path:  images/Test230.jpg
# image_path:  images/Test2791.jpg
# image_path:  images/Test1353.jpg
# image_path:  images/Test180.jpg
# image_path:  images/Test1161.jpg
# image_path:  images/Test227.jpg
# image_path:  images/Test979.jpg
# image_path:  images/Test536.jpg
# image_path:  images/5.jpg
# image_path:  images/1.jpg
# image_path:  images/Test3177.jpg
# image_path:  images/Test715.jpg
# image_path:  images/16.jpg
# image_path:  images/Test2424.jpg
# image_path:  images/Test2049.jpg
# image_path:  images/Test1788.jpg
# image_path:  images/14.jpg
# image_path:  images/Test2114.jpg
# image_path:  images/Test1717.jpg
# image_path:  images/Test761.jpg
# image_path:  images/Test232.jpg
# image_path:  images/Test216.jpg
# image_path:  images/Test3975.jpg
# image_path:  images/Test579.jpg
# image_path:  images/Test242.jpg
# image_path:  images/Test211.jpg
# image_path:  images/Test234.jpg
# image_path:  images/Test946.jpg
# image_path:  images/Test1884.jpg
# image_path:  images/Test1012.jpg
# image_path:  images/Test3625.jpg
# image_path:  images/Test244.jpg
# image_path:  images/Test396.jpg
# image_path:  images/Test158.jpg
# image_path:  images/Test2068.jpg
# image_path:  images/Test192.jpg
# image_path:  images/Test1022.jpg
# image_path:  images/Test2411.jpg
# image_path:  images/Test353.jpg
# image_path:  images/11.jpg
# image_path:  images/Test191.jpg
# image_path:  images/Test1229.jpg
# image_path:  images/Test1818.jpg
# image_path:  images/Test859.jpg
# image_path:  images/Test119.jpg
# image_path:  images/Test2650.jpg
# image_path:  images/Test3750.jpg
# image_path:  images/Test522.jpg
# image_path:  images/9.jpg
# image_path:  images/Test181.jpg
# image_path:  images/Test374.jpg
# image_path:  images/Test2235.jpg
# image_path:  images/Test449.jpg
# image_path:  images/Test482.jpg
# image_path:  images/Test231.jpg
# image_path:  images/Test490.jpg
# image_path:  images/Test141.jpg
# image_path:  images/Test198.jpg
# image_path:  images/Test942.jpg
# image_path:  images/Test526.jpg
# image_path:  images/Test1279.jpg
# image_path:  images/Test249.jpg
# image_path:  images/Test201.jpg
# image_path:  images/Test145.jpg
# image_path:  images/17.jpg
# image_path:  images/Test3525.jpg
# image_path:  images/Test179.jpg
# image_path:  images/Test131.jpg
# image_path:  images/Test1634.jpg
# image_path:  images/Test3246.jpg
# image_path:  images/Test668.jpg
# image_path:  images/Test884.jpg
# image_path:  images/Test3863.jpg
# image_path:  images/0.jpg
# image_path:  images/Test1359.jpg
# image_path:  images/Test834.jpg
# image_path:  images/Test151.jpg
# image_path:  images/Test1644.jpg
# image_path:  images/Test2371.jpg
# image_path:  images/Test824.jpg
# image_path:  images/Test360.jpg
# image_path:  images/Test612.jpg
# image_path:  images/Test135.jpg
# image_path:  images/Test1902.jpg
# image_path:  images/Test114.jpg
# image_path:  images/Test1992.jpg
# image_path:  images/Test209.jpg
# image_path:  images/Test3706.jpg
# image_path:  images/Test213.jpg
# image_path:  images/Test941.jpg
# image_path:  images/Test779.jpg
# image_path:  images/Test243.jpg
# image_path:  images/Test237.jpg
# image_path:  images/Test172.jpg
# image_path:  images/Test581.jpg
# image_path:  images/Test1620.jpg
# image_path:  images/15.jpg
# image_path:  images/Test3827.jpg
# image_path:  images/Test173.jpg
# image_path:  images/Test1199.jpg
# image_path:  images/Test789.jpg
# image_path:  images/Test587.jpg
# image_path:  images/Test100.jpg
# image_path:  images/Test134.jpg
# image_path:  images/Test2743.jpg
# image_path:  images/Test1615.jpg
# image_path:  images/Test2434.jpg
# image_path:  images/Test1724.jpg
# image_path:  images/7.jpg
# image_path:  images/Test194.jpg
# image_path:  images/Test1934.jpg
# image_path:  images/Test109.jpg
# image_path:  images/18.jpg
# image_path:  images/Test1271.jpg
# image_path:  images/Test250.jpg
# image_path:  images/Test1954.jpg
# image_path:  images/Test812.jpg
# image_path:  images/Test113.jpg
# image_path:  images/Test3864.jpg
# image_path:  images/4.jpg
# image_path:  images/Test136.jpg
# image_path:  images/Test1885.jpg
# image_path:  images/Test1803.jpg
# image_path:  images/Test239.jpg
# image_path:  images/Test2590.jpg
# image_path:  images/Test1776.jpg
# image_path:  images/Test835.jpg
# image_path:  images/Test533.jpg
# image_path:  images/Test108.jpg
# image_path:  images/Test233.jpg
# image_path:  images/Test2455.jpg
# image_path:  images/Test245.jpg
# image_path:  images/6.JPG
# image_path:  images/Test187.jpg
# image_path:  images/Test212.jpg
# image_path:  images/Test183.jpg
# image_path:  images/Test3030.jpg
# image_path:  images/Test422.jpg
# image_path:  images/Test516.jpg
# image_path:  images/Test1001.jpg
# image_path:  images/Test2792.jpg
# image_path:  images/Test2309.jpg
# image_path:  images/Test545.jpg
# image_path:  images/Test206.jpg
# image_path:  images/Test606.jpg
# image_path:  images/Test912.jpg
# image_path:  images/Test166.jpg
# image_path:  images/Test2280.jpg
# image_path:  images/Test1290.jpg
# image_path:  images/Test833.jpg
# image_path:  images/Test1071.jpg
# image_path:  images/Test397.jpg
# image_path:  images/Test1889.jpg
# image_path:  images/Test204.jpg
# image_path:  images/Test660.jpg
# image_path:  images/Test105.jpg
# image_path:  images/Test129.jpg
# image_path:  images/Test760.jpg
# image_path:  images/Test861.jpg
# image_path:  images/Test3294.jpg
# image_path:  images/Test3159.jpg
# image_path:  images/Test1923.jpg
# image_path:  images/Test843.jpg
# image_path:  images/Test117.jpg
# image_path:  images/Test164.jpg
# image_path:  images/Test2977.jpg
# image_path:  images/Test751.jpg
# image_path:  images/Test3798.jpg
# image_path:  images/2.jpg
# image_path:  images/Test811.jpg
# image_path:  images/Test218.jpg
# image_path:  images/Test440.jpg
# image_path:  images/Test993.jpg
# image_path:  images/Test417.jpg
# image_path:  images/Test661.jpg
# image_path:  images/Test1767.jpg
# image_path:  images/Test614.jpg
# image_path:  images/Test140.jpg
# image_path:  images/Test2648.jpg
# image_path:  images/Test188.jpg
# image_path:  images/Test133.jpg
# image_path:  images/Test1743.jpg
# image_path:  images/Test1872.jpg
# image_path:  images/Test122.jpg
# image_path:  images/Test890.jpg
# image_path:  images/Test144.jpg
# image_path:  images/Test2209.jpg
# image_path:  images/Test1122.jpg
# image_path:  images/Test3277.jpg
# image_path:  images/Test1856.jpg
# image_path:  images/Test3130.jpg
# image_path:  images/Test154.jpg
# image_path:  images/13.jpg
# image_path:  images/Test3934.jpg
# image_path:  images/Test161.jpg
# image_path:  images/Test903.jpg
# image_path:  images/Test3360.jpg
# image_path:  images/Test957.jpg
# image_path:  images/Test498.jpg
# image_path:  images/3.jpg
# image_path:  images/Test128.jpg
# image_path:  images/Test238.jpg
# image_path:  images/Test107.jpg
# image_path:  images/Test240.jpg
# image_path:  images/Test132.jpg
# image_path:  images/10.jpg
# image_path:  images/Test3566.jpg
# image_path:  images/Test3512.jpg
# image_path:  images/Test3893.jpg
# image_path:  images/Test757.jpg
# image_path:  images/Test372.jpg
# image_path:  images/Test152.jpg
# image_path:  images/Test519.jpg
# Ktr:  1
# 100%|██████████| 2/2 [00:06<00:00,  3.37s/it]
# image_path:  images/Test644.jpg
# image_path:  images/12.jpg
# image_path:  images/Test937.jpg
# Ktr:  2

# %%
myRevList = os.listdir(folder_path)

# %%
import re
lstImage_text = []
# initializing bad_chars_list
bad_chars = [';', ':', '!', "*", "{", "}"]

for image in  myRevList:
    try:
        #print(f'Working on - {folder_path}/{image}')
        img = cv2.imread(f'{folder_path}/{image}')
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        text_data = pytesseract.image_to_string(img_rgb)
        regex = r"([\w ,]+)\n(?:([\w ,.]+)\n)?(\(\w+ \d+, \d+\)\d*)"
        subst = "$1$2 $3"
        text_data = re.sub(regex, subst, text_data, 0)

        text_data = re.sub(r"(http[s]?\://\S+)|([\[\(].*[\)\]])|([#@]\S+)|\n", "",text_data)
        text_data = re.sub('\s+',' ',text_data)
        text_data = re.sub('\n+',' ',text_data)
        text_data = ''.join((filter(lambda i: i not in bad_chars, text_data)))
        
        lstImage_text.append((image, text_data))        
        
        #cv2.imshow("Image", img)
        #cv2.waitKey(0)
        #cv2.destroyAllWindows()
    except:
        pass

# %%
image_embeddings = dict(zip(image_paths,embeddings))

# save to pickle file for the app
print("Saving image embeddings")
with open('embeddings.pkl','wb') as f:
    pickle.dump(image_embeddings,f)
# Out:
# Saving image embeddings

# %%
lstImage_text
# Out:
# [('Test250.jpg', ' WWW.GDBLOG.NET '),
#  ('Test230.jpg', 'Top Pro & ConQuotes '),
#  ('Test3159.jpg', '4 '),
#  ('Test2870.jpg',
#   ' Woe) ee the stem ELL) eel eean alien from outer space.. its funny” '),
#  ('Test1717.jpg', '1009 MIE“of aCag '),
#  ('Test482.jpg', 'We are legal In all fifty states '),
#  ('Test1620.jpg', ' LOVEIS TOO BEAUTO BE HIDIN THE CLOior '),
#  ('Test1856.jpg',
#   " It's funny how we know gaypeople exist and we don’thave proof of God but weee uous eeEta tated pied esos Pe)NM ke eee ekee Being Gay & Proud Quoteswww. geckoandfly.comi» OR Wiz Tin . ] ke Bi "),
#  ('Test581.jpg',
#   '‘There are poop have said that Pmmeng trace for being pends sopperticefy marriage. gy ateption. Whidee renpecthmbty det. bom(met Mrng brane Pa deers bameimg- Love lea human experience,et peta tater '),
#  ('Test1902.jpg', ' Se aCe en asCard———] '),
#  ('Test129.jpg', ' '),
#  ('Test2371.jpg',
#   "When people askwhat I see in you,I just smile andlook away becauseT'm afraid if they knew,they'd fall in lovewith you too. "),
#  ('Test519.jpg', ' © dreamstime.com ID 145823917 © Barrirret '),
#  ('Test946.jpg',
#   '“Tam not freewhile any womanis unfree, evenwhen her shacklesare very differentfrom my own.”AUDRE LORDEGH '),
#  ('17.jpg',
#   'See back of receipt for your chanceto win $1000ID 7K2GF1SL2FFlalWalmart >,<Save money. Live better, 259 ~ 8755MANAGER MIKE NEIDLINGER1165 S CAMINO DEL RIODURANGO CO 81303ST# 02270 OP# 000144 TE# 02 TR# 03080|ANANAS 00000000401 1KIxOo2a.16 lb @ 1b /0.,BEVERAGE 003120002133 FOH 00312010098211 FAHI 020533960343 FVOCADO 000000004046KT4 AT 1 FOR 0.4PILLS WHITE 068113113619 FSH NYLON COL 007417024836HAND CLEANER 004125100005INJECTR CLNR 004980710003SUBTOTALTAX 1 7,900 TAX 2 6.000 %TAX 5 2.900 %TOTALxxx<2 <<<2<Dwstaan on Bee wooSSSnxQHSINSa asaexssmone te) 8 Be an aSah ATAOW/IB/IT 1452603 '),
#  ('Test133.jpg', ' '),
#  ('Test1889.jpg', ' '),
#  ('Test2068.jpg', ' ay hiaca> A eis '),
#  ('Test2590.jpg', ' '),
#  ('Test1359.jpg', ' '),
#  ('Test109.jpg', ' '),
#  ('0.jpg',
#   'WALMARTALWAYS LOW PRICES.woe SUPERCENTEROPEN 24 HOURSMANAGER . TBA 986 - 1783S1# 5748 OP# 00000158 TE¥ 14 TRH 03178BANANAS 00000000401 1kF0.41 Ib @ 1 Ib /0.49 0.20 NFRAP 001200010451 F 5.48 NDISCOUNT GIVEN 0.57J SUBIQTA. 8.115y CASH TEND ©1100CHANGE DUE “5 “gg '),
#  ('Test677.jpg', ' '),
#  ('Test1785.jpg',
#   'To be afraid isto behave asif the truth werelake mada el—eTV N7C ON Ure _ '),
#  ('Test1788.jpg', ' '),
#  ('Test172.jpg', ' '),
#  ('Test188.jpg', ' '),
#  ('Test206.jpg', ' '),
#  ('Test3525.jpg', ' Do you realize what yousay. when you sa’That s so gay"? '),
#  ('Test1353.jpg', ' '),
#  ('Test141.jpg', ' '),
#  ('Test3985.jpg', ' '),
#  ('Test3798.jpg', ' '),
#  ('Test221.jpg', ' '),
#  ('14.jpg',
#   'See back of receipt for your chanceto win $1000ID 7LORX4K8PUXieWalmart 2,5Save money. Live better.DBLVIST# 01595 OP# 007573 TESEQUATE LINER 068113186503WFUS ENG POM 005100024543 FDAWN ORIG 00370001 1045BOYD PKGTAPE 007535307841BOYD PKGTAPE 007535307841LINT ROLLER2 005114123488SUBTOTALTAX 1 7.000 %TOTALDEBIT TENDCHANGE DUEnsw07 S05 00Bascon> EeRR RoieSSsuSEFT DEBIT PAY FROM PRIMARY26.60 TOTAL PURCHASEACCOUNT # eee weer Jaeee §371REF # 712400283994NETWORK ID. 0069 APPR CODE 868483TERMINAL # SCO1008705/04/17 195416# ITEMS SOLD 6ul vii wil wav05/04/17 195418Store receipts on your phone. Walmart Pay. '),
#  ('Test1022.jpg', 'LOVE® '),
#  ('Test1884.jpg',
#   'y” Kt es heard 50 ga icrous. nalv uiirrational. interesting, curioueccentric. bogus. . foolish.gooty. insipid. absurd. ridiculous.an . asinine. .OO Og aa nasal weet '),
#  ('Test240.jpg', ' '),
#  ('Test187.jpg', ' '),
#  ('Test522.jpg',
#   ' “The pressures on gay teens cancheba tlie ceslagtesantetandS LawtetiduipheglnciureddoerPeete hien |‘Cared about. loved. and acceptedSo eeererneanensCe eePerens '),
#  ('Test3863.jpg', ' '),
#  ('Test211.jpg', ' '),
#  ('Test957.jpg', 'Mh Wk GAY ISAASU aL LE '),
#  ('16.jpg',
#   " See back of receip’to win $1000ID 7L2T9WJM25F Walmart >/<.Save money. Live better. 223 - 3066MANAGER TIM MORRIS2717 ROCK ISLAND PLBISMARCK ND 58504ST# 01534 OP# 009048 TE# 48 TRH 04455 6 WING PLATE 020108870398 3.98 PASST 27 063099656595 4.88 XCUTIE CAR 063099656644 12.88 XSUBTOTAL 21.74TAX 1 6.500 % 1.15TAX 4 7.500 %& 0.30TOTAL 23.19DEBIT TEND 23.19CHANGE DUE 0.00 EFT DEBIT PAY FROM PRIMARY23.19 TOTAL PURCHASEUS DEBIT xxKK xxx xxxx 2696 I 0REF # 731700494718NETWORK ID. 0081 APPR CODE 936886US DEBITAID A0000000980840TC 58B77239DA5B3B44NO SIGNATURE REQUIREDTERMINAL # SCO1109011/13/17 123404# ITEMS SOLD 3TC# 2188 7274 6444 1567 3762NUMii Low Prices You Can Trust. Every Day.' 11/13/17 123411Store receipts on your phone. Walmart P= | "),
#  ('Test2977.jpg', ' '),
#  ('Test143.jpg', ' '),
#  ('Test227.jpg', ' '),
#  ('Test149.jpg', ' '),
#  ('Test2309.jpg',
#   '74Find out who you areand be that person.BiaT\\a-a 101-1 a—el8 |.was put on this earthto be. Find that truth,live that truth, andeverything else Fs71 lil ~ Yae 99 '),
#  ('Test516.jpg', "THERE'S NOTHINGWRONG WITH YOU.THERE'S ALO "),
#  ('6.JPG',
#   'MOMI & TOY’SCREPERIETepe Mall Kemang, L.emang VI No. 6momiantoys_ind Cinst Ctwitter)Check 3850Pax OP Gunawan GunawanPOS TitleCashierna 26/01/2018 16131 Woman 02 Ham Cheese 74, 0001 Ice Java Tea 16, 0001 Mineral Water 13, 0001 Black & White 72, 000SUBTOTAL 175, 000TOTAL 175, 000CASH 200, 000Change 25 Closed Bil]ween enn en n= 26/01/2015 16 14----------->Thank you for tastingour “Meltingly Crepe" '),
#  ('Test135.jpg',
#   'So you oppose gay rightsbecause of the Bible?Unless you also try to outlaw-Shrime cocktails -Cursing -Women’s jeans -Arrogance -Lying -Bacon -Adultery -Workirg on Suriday please shut the hell upl '),
#  ('Test422.jpg', ' '),
#  ('Test216.jpg', ' '),
#  ('Test2007.jpg', 'jamWe are powerfulbecause we havesurvived.il AUDRE LORDE '),
#  ('Test212.jpg', "['aD "),
#  ('Test3706.jpg',
#   '‘Shine your soul with the same egoless humilityFe nT hen 700 goin this world or the next, love will find you,attend Gless you." ——A>= ee 7aAS Aberjha , =pthrough the P in= y 8° ant by Saraa — '),
#  ('Test861.jpg', ' '),
#  ('Test168.jpg', ' '),
#  ('Test400.jpg',
#   " Being gay is like beingleft handed. Some peopleare, most people aren'tFete eee ares VE Ceated ieee ceeit’s just the way things are2 Being Gay & Proud Quoteswww. geckoandfly.com. we Ff? ) 2S 2S "),
#  ('Test3566.jpg', ' '),
#  ('8.jpg',
#   'Thornton 16375 N. Washington St.Thornton, CO 800232X Member 111826278335E 673919 FF BS BREASTE 633561 KS DICED TOMEI 967596 JACKORGSALSA38 4.29— 878137 18CT EGGSE 77053 GRAPE TOMATO404609 ECO HALF PANE 55992 GRND TURKEYE 263423 CHPD ONIONE 22101 MONT JACK 2#SUBTOTALTAXseen TOTALCheck/Member PrntdCHANGEA 8.50% TAXE 3.75% TAX 2.97TOTAL TAX 3.52TOTAL NUMBER OF ITEMS SOLD = 11‘wey 1500 629 4 172 14op 14 Name PEPPERThank YouPlease Come AsainWhse629 Trm4 Trn172 OP14 '),
#  ('Test803.jpg', ' '),
#  ('Test606.jpg', 'TANSciOT EXIST '),
#  ('Test1934.jpg', ' '),
#  ('Test833.jpg',
#   'HATEIt HAS CAUSED A LOTOF PROBLEMS IN THISWORLD, BUT IS HASNOT SOLVED ONE YET.-Maya ANGELou '),
#  ('Test1279.jpg', ' '),
#  ('Test3864.jpg', "ae odMLC yOOI's that no oneCee "),
#  ('Test941.jpg', 'eeeTOOeaCR Re eel '),
#  ('Test213.jpg', ' '),
#  ('Test1743.jpg',
#   "‘She just Lept storing ather. she lamented. “ite | awosn't even there® 4“The trouble with lesbianlove triangles is you can't‘tell which ‘she’ and which m4‘ner’ we're talking abovt.~ Molly Ringle "),
#  ('Test2616.jpg', ' CO"to behe " '),
#  ('Test812.jpg', "Life's a game. Play to win. "),
#  ('Test660.jpg',
#   'Se aadee ee eesrs dadces 7 ea‘The important fact is that |Aant Wise dheapey hops) Oak '),
#  ('Test1923.jpg',
#   'Ce a eyAe StagTHE RECENT RISE IN HOMOPHOBICPts ea ated a 4Beret gus dat [les '),
#  ('Test644.jpg', 'aASTANDING UP FOR YOURDIAS N 3YOU STANDING ANDSESErace '),
#  ('Test587.jpg', 'STUNDS '),
#  ('Test166.jpg', ' '),
#  ('Test1724.jpg',
#   'ote SF > =a tbeon ‘agedy in theirVPP e Ake eat TelTem tev hwar ctl aed—_ ff '),
#  ('Test236.jpg', ' '),
#  ('Test449.jpg', 'the UN is anythingbut neutral '),
#  ('Test249.jpg', "eeeele'  "),
#  ('Test979.jpg', ' '),
#  ('Test3130.jpg',
#   'a ed areOdto be norm.you will never knowea Seareaie)oesa chia '),
#  ('Test835.jpg', 'SOUNDS '),
#  ('Test242.jpg',
#   '“You either say how you feel and fuckit up or say nothing and let it fuck you‘up instead.” '),
#  ('Test3789.jpg', ' '),
#  ('Test2650.jpg', ' '),
#  ('Test225.jpg', ' '),
#  ('Test2049.jpg', ' '),
#  ('2.jpg',
#   ' Give us feedback @ survey.walmart .comThank you ID Walmart >\\<949-498-6669 Mor  wae951 _AVENIDA PICOSAN CLEMENTE CA 92673ST# 02527 OP# 009045 TE# 45 TR¥ 06193GV OATMEAL 007874243408 F = -1.76 0OT 2002 TUM 081236803115 6.74 XM ATHLETICS 019104567781 24.97 XDEXAS 15X20 008429710921 12.97 XSUBTOTAL 46.44TAX 1 7.750 % 3.46TOTALDEBIT TEND 49.90CHANGE DUE 0.00DEBIT PAY FROM PRIMARY49.90 TOTAL PURCHASEUs DEBIT axxx naxx trex 9689 I 0REF # 029200639128NETWORK ID. 0056 APPR CODE 461500US DEBIT1004ae 113042wii iid+Ritroduciny Walmart+Join today at walmarL.cony/plus ‘ices You Trust. Every Day.bow Pe era” Tt8046 '),
#  ('Test396.jpg', "cd“There's nothingwrong with you.Abst 9 aedSRR ot Booa a "),
#  ('Test2792.jpg',
#   " See eeePree cae et Retence ene)Ceo et er)Cee kre Tytaker i Ad aedwhat makes people so cruel. Try beingeeeyou're as good as dead.”a) "),
#  ('Test108.jpg',
#   "trased on or was the outcome of the perception and attitudes of the audience toward . Themajority believed that portrayal of the LGBT commundy in Indian movies was montly negative,whale the same in western movies was ponitive und precise. Even though the negative putrayal‘of the LOOBT themes in Indian cinema was pointed out the improvements that have been madewere ached podFollowing «© the evidence of quotes of the participants for each theme which isthe source of thediscussion,Accurate portray al in generat“Gemorally I wenadd sary... they. the portrayal ts gow ~“See. some LGBT movies are good, amd some are ust chaammna make for time pass, forenerisinaent Bat the mes mace with efor and all w labs be gonad ~ old move and wh. it's it's grout becuase the mumber of LGBT monies which really haveLGBT theme and also have some substance in them are very less. and even though they areess... 1h they are goo ~ ‘The current theme refers to the accurste portrayal of the LGBT community in movies. SomeParticipants stated that efforts of movies to make the actual depiction of the LOBT life waspaying off hecause they were ampron ing an beth content and portrayalInaccurate portray al tn Indian me vies“Wear re speaking ast Indian moves the are mot at all accra became they ave mieswhat LGBTQ means”tm thes Keanmends film she be tihimg that wermuan tat sumdchemts che likes that guy Bt s (ihe hemcam she do that? When you're krving like. that other girl all of a sudden she ges away andsaachdenly yom Tl te Bike within seconds you Tl like that guy How ts that ever promsitble”~ "),
#  ('Test160.jpg', ' '),
#  ('Test837.jpg', 'Pe ea tsBOYS OR GIRLS? iow ’ '),
#  ('Test3749.jpg', 'UAV ATTMeLa hiretHaagrN '),
#  ('Test397.jpg',
#   '7Back then my © .denial was both active Co —and passive.Caught shadowboxingmy subconscious, I wasdetermined to dodge the danger ofmy natural desires. '),
#  ('Test523.jpg', 'ClO) Dycieras wa '),
#  ('Test173.jpg', ' '),
#  ('Test232.jpg', ' '),
#  ('Test661.jpg', "IF 1 FALLASLEEP.CAUSE |DIDN'T WANT TOSAY GOODBYE. "),
#  ('Test209.jpg', ' '),
#  ('Test3265.jpg',
#   ' Alot of parents willeR amePete ee ici pcs Moyc2 Being Gay & Proud QuotesRL OA AC)aS. a_ © | ae '),
#  ('Test1776.jpg',
#   ' Of course gay menteas eel asspend all that time inthe closet doing nothing.a2 Being Gay & Proud Quoteswww. geckoandfly.comif '),
#  ('Test191.jpg',
#   "JasonJ &jaybs121|4| = Added Me Everyone add my newSnapchat or commentnames below. I'll be postingpositive quotes every day ©Igbtpride loveislove Igbt transtransmatter transgendertransgirl transmale lesbianlesbiansex gaypride gay bibisexualpride bisexual biprideasexual asexualpridepansexualpride pansexualprotecttranskids pride swag ftmmtf "),
#  ('Test378.jpg', "KEEPCAIMBECAUSE IT'S OKAY "),
#  ('Test2114.jpg', ' '),
#  ('Test1803.jpg', ' '),
#  ('Test751.jpg', ' '),
#  ('Test929.jpg',
#   'Happinessres hen whatyou Stal aewhat yousay,andWasi a\\8)doareinharmony teInspiring and Positive Quotes <3 '),
#  ('Test117.jpg', ' '),
#  ('1.jpg',
#   "“TRADER JOE'S2001 Greenville AveDallas TX 75206Store - 334-0614OPEN 800AM TO 900PM DAILYR-CARROTS SHREDDED 10 OZR-CUCUMBERS PERSIAN 1 LBTOMATOES CRUSHED NO SALTTOMATOES WHOLE NO SALT W/BASILORGANIC OLD FASHIONED OATMEALMINI-PEARL TOMATOES . .PKG SHREDDED MOZZARELLA LITE TEGGS 1 002 ORGANIC BROWN.BEANS GARBANZO.SPROUTED CA STYLEA-AVOCADOS HASS BAG ACTA-APPLE BAG JAZZ 2 LBA-PEPPER BELL EACH XL REDGROCERY NON TAXABLE2 @ 0.49BANANAS ORGANIC3FA —«CREAMY SALTED PEANUT BUT TERWHL WHT PITA BREADGROCERY NON TAXABLE2 @ 0.69WoOwONNHHH——Digm io Rm MininiohySSSESSESESBSUBTOTAL 3TOTAL $38.68CASH $40.00CHANGE $1.32ITEMS 22 Higgins, Ryan06-28-2014 1234PM 0403 04 1346 4683THANK YOU FOR SHOPPING ATTRADER JOE'Sww. traderjoes .com "),
#  ('Test372.jpg',
#   'GAY CULTURE IS SURVIVINGAND THRIVING.\\CTIVISTS BELIEVERECENT en INHOMOPHOBIC VIOLENCEMIGHT BE A GAUGE OF THESUCCESS OF POSITIVE GAYIMAGE S. '),
#  ('Test1290.jpg', ' '),
#  ('Test3750.jpg', 'se oa adCOLO50It’s that no oneCe od '),
#  ('Test859.jpg', 'myth that all femalMriendships must be '),
#  ('Test3277.jpg', 'ydSettee |live that truth, andwk 9° '),
#  ('13.jpg',
#   ' TD i A ASWOVBKCH Walmart >/<.Save money. Live better. 292MANAGER MICHAEL2014 S TRBY ST FLORES1# 02/03 OPH 009049. 11GIPT CARD 087458604 50,00 0‘SUBIO AL 90.00,TOTAL 50.00,CASH TN) 60.00CHANGE (UE 10.06SHOP CARL ACTIVATION 50.00ACCOUNT 6139685424929 +APPR. CODE — 792986.REF MOuE37A2Beg Bal fran Amt End Bal0.00 50.09) 50.00O/T 17 191931ICH 9796 5895 92387 0933 1992ATTALow Prices You Catt Trust. Every Day.OBIT 192240) ‘Store receipts O71 your noone. Walmart Pay. '),
#  ('Test3246.jpg', 'LOVE®@eve '),
#  ('Test945.jpg',
#   'HATEIr Has causED ALOT ©OF PROBLEMS IN THISWORLD, BUT IS HASNOT SOLVED ONE ¥ET.-Mava AxceLou '),
#  ('Test244.jpg', ' '),
#  ('Test824.jpg', ' '),
#  ('Test2962.jpg', 'TNCeeeedcil ansool \\seta) BEpoe THAT '),
#  ('Test624.jpg', ' '),
#  ('Test912.jpg',
#   ' ‘or all, alStand up andstart to fight.Harvey MilkQBavirgimages.com '),
#  ('Test1229.jpg',
#   'a coumea Rua Reh)a kid, | have neverbeen able tounderstand attacks upon the gaycommunity. There are so manyqualities that make up a human being...by the time | get through with all thethings that | really admire about people,what they do with their private parts isprobably so low on the list that it is irrelevant.Sem =) i tite Lt eer '),
#  ('Test233.jpg', ' '),
#  ('Test890.jpg',
#   'The Biblical Case inSupport of Same-SexRelationshipsGia lncee urayMATTHEW VINES '),
#  ('Test198.jpg',
#   'Anti-LGBT States that have laws restricting teachers and staff fromtalking about LGBT issues at school '),
#  ('Test715.jpg',
#   'Gay culture issurviving andthriving. SomeElls mie ksi Ib Cac aarecent rise inhomophobic violencemight be a gauge ofthe success ofeA REC Nab bere oeSere BAC g '),
#  ('Test884.jpg', "“Be lieveyou canyou're halfwaythere.T. ROOSEVELT "),
#  ('Test3975.jpg', ' '),
#  ('Test937.jpg', 'you are¥ LOVABLEFWORTHYY ENOUGHWw BRAVE '),
#  ('Test1837.jpg', 'oe '),
#  ('Test238.jpg', ' '),
#  ('Test1818.jpg', ' '),
#  ('Test545.jpg', ' '),
#  ('Test1615.jpg',
#   ' Slowlerukectioeesrema’eesa SSeSaaereene terspeor iotrngeinnano terialcopereee restoscee aenioseee traea nearcree '),
#  ('Test1872.jpg',
#   " Being gay is like beingleft handed. Some peopleare, most people aren'tFete eee ares VE Ceated ieee ceeit’s just the way things are2 Being Gay & Proud Quoteswww. geckoandfly.com. we Ff? ) 2S 2S "),
#  ('Test668.jpg', '@to the rights ofthe UN is anythingbut neutral. M '),
#  ('15.jpg',
#   '—_— >nFor abtek of of receipt for your chant / TD & — qyyy2uuoKsy AgszaneWalmart 7,5Save money Live better- © 714 2799 = 0020, (02Y THOMAS ‘5wee VONNE Ten peJES THIN 3ST# 02495 MO 006969 TES. eeDiapers 66113131172 ww ieVisa TEND 510 Credit wwwx annx wwe 3670 11 wtpePRovaLs 222238 |REF & 620800604 TRANS ID ~ Béegayt25ee40coVALIDATION .PAYMENT Stevie = -E obAID AO000000031010TC 9EOFACSAB09EBD92TERMINAL # 281767447. SIGNATURE REQUIRED07/22/16 205311 jCHANGE DUE 0.00 |# ITEMS SOLD130129 11wl wi ii ji"eotea ners DeiS ‘Cala COPY xR‘Ings Catcher Scan with Wa Inart app‘ weez WS BOI Is.bioV esbeUOY winan '),
#  ('Test778.jpg', ' '),
#  ('Test811.jpg', ' '),
#  ('Test3827.jpg',
#   'Being gay is not a crimeand it is not a sin. Stop usingGod to justify your prejudice.Nee erelee lim eu ieme gsFU mM CUM Cey mee isdse) elie Cem CO 1K)ee Being Gay & Proud Quoteswww. geckoandfly.comi ——_ '),
#  ('Test374.jpg', ' '),
#  ('Test2411.jpg',
#   " ONE DAYWON'T HAVE TO“COME OUT OFTHE CLOWE'LL JU 4WE ARE I VEPS TY L BEPNR) "),
#  ('Test234.jpg', ' '),
#  ('12.jpg',
#   ' WALMARTSave money. Live better.WE SELL FOR LESSALWAYSMANAGER DAPHNE SESSIONne 636 ) 536 - reaIESTERFIELD, MO 6ah 2600" OF 00001855 Te ie TRE CrW FIGURES 065356920144 6.63TOOTHBRUSH Soe an - e iWOMEN SLIPPE Ce ae xiy . 4)TAX 4 3 S10 qe 0.54TAX 3 4.350% 076TOTAL 18.75MCARD TEND 18.75ACCOUNT APPROVAL TRANRANS ID -VALIDATION -PAYMENT SERVICE - ACHANGE DUE 0.00# ITEMS SOLD 3Sin 4Wal-Mart exclusiv available Sta stn10/20/07 134843 COPY '),
#  ('Test122.jpg', ' '),
#  ('Test1767.jpg', ' '),
#  ('Test3512.jpg', ' '),
#  ('Test1240.jpg',
#   'ee)totheDeteve big events such as the Finalhohe eskonmsndeeleeda '),
#  ('Test2434.jpg', ' '),
#  ('4.jpg',
#   "Walmart >'<Save money. Live better. 366 ~ 3326MANAGER DONALD MONEYMAKER3201 MANAUA CENTRE DRCOUNCIL BLUFFS T@ 61601ST# 01965 OPS 00203) J5E,20 TRe 061465SW HRO FGHTR 06306094073 6.94 TSUBTOTAL 6.94TAK 1 7.000 % 0.49143‘DEBIT Ta 7.43CHANGE DUE 0.00EFT DEBIT PAY FROM PRIMARY7.43 TOTAL PURCHASEACCOUNT 0 HH OE ESREF & 534200381765NETWORK ID. 0056 APPR CODE 087193TERMINAL # MX99502612/08/15 123924# ITEMS SOLD 1TCR 3261 4114 0323 3051 6498wii Winnto midnight 7 dave a week.as sor oarts 123926Savings Catcher Scan with Walmart aprBaviel "),
#  ('Test3934.jpg', ' '),
#  ('Test183.jpg', 'dail) m7iryMig”zwu—eo°14caFavyvy- '),
#  ('Test2743.jpg', ' '),
#  ('Test192.jpg', ' '),
#  ('Test164.jpg', ' '),
#  ('3.jpg',
#   'See back of p,to win $1000 Th)UR NCIRG SO _norBis Br BLON | EA 124_BTS ORY 10 HegreTR HS FRM 4 Sozesotezi98BAGELS 1013GV SLIDERSACCESSORY 61CHEEZE ITWAS 4.54 YOU SAVSensSS8S28S2 SNeRzR. Goa 00RUFFLES 10020942 FGV HNY GRHS OaTeTaOTzES FiSUBTOTALTAX 1 7,000 %anrtesia ionScan vith Galrart app ee cap receipts‘sa Ta]zzz oxxoxrySoomauani622)420422)159440,6. '),
#  ('Test527.jpg',
#   'Gay pride or LGBT pride is the positive stance againstdiscrimination and violence toward lesbian, gay,bisexual, and transgender people to promotetheir self-affirmation, dignity, equality rights, increasetheir visibility as a social group, build community, andcelebrate sexual diversity and gender variance. Your '),
#  ('Test1071.jpg',
#   "eee MU WALLA OLem eat nimeel ienot living by society'sstandards, but deep down,they wish they had thecourage to do the same.we Being Gay & Proud Quoteswww.geckoandfly.comes "),
#  ('Test1992.jpg', " Colt) NGSTEAIGHT'Ve gsRAINBOW’a "),
#  ('Test245.jpg',
#   'Anti-Bullying States that have laws prohibiting bullying of students onthe bases of sexual orientation and gender identity Massachusetts,Minnesota f, xNevadaNew Hampshire <——éNew JerseyNew YorkNorth CarolinaRhode IstandWashingtonWashington, OC '),
#  ('Test180.jpg', ' '),
#  ('Test181.jpg', ' '),
#  ('Test2648.jpg', ' '),
#  ('Test100.jpg', ' '),
#  ('Test239.jpg',
#   'learned this the hard way...“You either say how you feel and fuckit up or say nothing and let it fuck youup instead.” '),
#  ('Test1885.jpg', ' '),
#  ('Test154.jpg',
#   'Few Say Being LGRT Is 4 NegativeFactor in Theis iteey er raat areenn pateeet=— = -—eons, p> | ” '),
#  ('Test526.jpg', 'eaee '),
#  ('Test440.jpg', ' '),
#  ('Test1161.jpg', ' '),
#  ('Test789.jpg', 'pee)not wholly affected by theees— '),
#  ('Test417.jpg',
#   "Ue AC eePe nt ed cc en‘ol CUR CMU RagD to be who you're not. Remember) you ECE eT UTR egCC a leeoe oR CEM mg odCe ee Ue Be ea ae ead "),
#  ('Test114.jpg', ' '),
#  ('Test2791.jpg',
#   'Zeigler, author of "Fair Play How LGBT Athletes are Claiming theirRightful Place in Sports," defied the notion that sports are inherentlyhomophobic. Part of what is keeping gay athletes closeted, Zeigler said, isthe hyper heterosexism that exists in locker rooms. Negative talk aboutgay people is not the issue. Instead, it\'s the demeaning talk about women. '),
#  ('Test490.jpg', ' '),
#  ('Test3177.jpg', 'UVESPOryf '),
#  ('Test204.jpg', ' '),
#  ('Test136.jpg', 'eSP > '),
#  ('Test1199.jpg',
#   'Do ~~ realize what you_ when you saere so gay"?The way “gay” is used now-a-days has anegative connotation. Which it should not means brightly colored. happy and or homosexualWEAK. BOGUS. RIDICULOUS.FRIVOLOUS. CHILDISH.ABSURD.AWKWARD.oRFREAKY.CHOOSE A WORD WHICH MEANS,WHAT YOU MEAN TO SAY.IT\'S ONLY THE SMART THING TO DO.te '),
#  ('Test536.jpg', ' '),
#  ('Test151.jpg', ' '),
#  ('Test145.jpg', ' '),
#  ('Test3024.jpg', ' '),
#  ('19.jpg',
#   ' eS te |i ‘eetbec= Thank yout 10 Wi 7ODRII99R NI art, comSk | Walmart sc- 576-9425 Mar ~~ s eee STATE ROAD furte> | ST# 00859 oP# Ey<> | GRILL Cover 471288996937°° cat @ - FIBER CHOICE (096926600904 12.94 N .S. CELERY HEART 003838965301 2.48 N~ Soe le Mette= SJ 2.51 1ba ’ UBTOTAL ga 04 = TAX 1 000 x 1.05Tot TAL 3505- SHOPPING CARD TEND 3595,=e CHANGE DUE 0.00SSS SHOP.CARD REDEMPTION 35.05 ~SSS | ACCOUNT xxxxxxxxxx%x(246 ~— go Beg Bal Tran Amt End Bal157.29 35.05 122.24oat ITEMS san i a ISorie/21" 7 Coe Wh$ '),
#  ('Test126.jpg', ' '),
#  ('Test161.jpg', ' '),
#  ('Test1634.jpg', ' '),
#  ('7.jpg',
#   " See back of receip’to win $1000ID 7L2T9WJM25F Walmart >/<.Save money. Live better. 223 - 3066MANAGER TIM MORRIS2717 ROCK ISLAND PLBISMARCK ND 58504ST# 01534 OP# 009048 TE# 48 TRH 04455 6 WING PLATE 020108870398 3.98 PASST 27 063099656595 4.88 XCUTIE CAR 063099656644 12.88 XSUBTOTAL 21.74TAX 1 6.500 % 1.15TAX 4 7.500 %& 0.30TOTAL 23.19DEBIT TEND 23.19CHANGE DUE 0.00 EFT DEBIT PAY FROM PRIMARY23.19 TOTAL PURCHASEUS DEBIT xxKK xxx xxxx 2696 I 0REF # 731700494718NETWORK ID. 0081 APPR CODE 936886US DEBITAID A0000000980840TC 58B77239DA5B3B44NO SIGNATURE REQUIREDTERMINAL # SCO1109011/13/17 123404# ITEMS SOLD 3TC# 2188 7274 6444 1567 3762NUMii Low Prices You Can Trust. Every Day.' 11/13/17 123411Store receipts on your phone. Walmart P= | "),
#  ('Test3625.jpg', ' '),
#  ('Test105.jpg', 'a =Ss '),
#  ('Test243.jpg', 'LGBTQ FREEDOM= Middle Ea '),
#  ('Test119.jpg',
#   " Verizon LTE 1047 AM &— 34%| apologize for anything negativeI've said towards gays and for thatmatter anyone. | was young,ignorant, stupid, and in a badplace. I've moved on and learnedfrom my mistakes and | am sotruly sorry to anyone | haveoffended. | have nothing againstanyone or anything that promotesequality. Sorry again |9 Ca)QIWIETRETLYFUTILFOIP AISIDIFIGIHIJPKEL my Z)X\\C V\\B N M ieGee a eee "),
#  ('18.jpg',
#   ' feThank yoneedbackWalmart oie863-918-07597450. CYPRESS oat MARK @ six1D W7onta7i Smeal Met com5S_GARDENSny BLVDL 99884 TEW 36 .OOTBraBa5i91 p TRY 06386De A288181 Fl° Giogoo e/ 4206203 F 2.84 NQ 17874206203 F 284 N(03700077007 6.97 x903700076954 4194 x007874221000 F 7.82.NObaoo0050533 F 378 x003400029305 F 4.76 X004000047587 F 13.24 X004326880002 F 1.78 XHY RSTLEG py 008/00082385 1.97 XBATTERT G PM 035497333521H 9.97 NGV 200 tay, 001280051783 10.97 XCRNaRY LINE 007874219999 2.97 XSPI f v SAUCE 003120001605 F 1.58 0SPREADS 002740026499 F 3.46 0S6CT 007874212709 F090 0SUBTOTAL 82.75TAX 1 7.000 % 3.60TOTAL 86.35DEBIT TEND 86.35CHANGE DUE 0.00EFI DEBIT PAY FROM PRIMARY 86.35 TOTAL PURCHA’FIFTHTHIRD DEBIT xx xxxx xxx 9832 1 0REF # 130400725877NETWORK ID. 0076 APPR CODE 001740US DebitATU A00N0000042203AAC A8FABF3D0FD07485RMINAL # SCO11151 2Ms 10/31/21 100822# ITEMS SOLD 18 il10/31/21100821 iui '),
#  ('Test134.jpg', ' '),
#  ('Test843.jpg', 'LOVENOT GENDER '),
#  ('Test903.jpg',
#   'EMPOWER YOURSELFPag) ienasieLOVEwe owattonaldeni ‘2a FY ees '),
#  ('Test152.jpg', ' '),
#  ('Test498.jpg',
#   " eae ee eisaR alee cee lzel pcinmr eca che sli grsdangry with someone foreating a donut whenyou're on a diet.2 Being Gay & Proud Quoteswww. geckoandfly.com000 le ee "),
#  ('Test132.jpg', ' '),
#  ('Test194.jpg', ' '),
#  ('Test942.jpg',
#   '“Lam not freewhile any womanis unfree, evenwhen her shacklesare very differentfrom my own.” '),
#  ('Test2235.jpg', ' '),
#  ('Test834.jpg',
#   '“Bach time awoman stands upfor herself, withoutknowing it possibly,without claiming it,she stands up forall women.”mara amoniow '),
#  ('Test2455.jpg', ' '),
#  ('Test3030.jpg',
#   " “Onstage, | am a devil. But I'm hardly asocial reject.”eee ae) "),
#  ('11.jpg',
#   'WHOLEFOODSSHARON RD.PL TORTILLA’S 6.CAGE FREE ALL WHIT 3BLACK BEANS 1Frozen Mangoes 160 2Whole Strawberries 20G LF COTTAGE CHEE s822MAHI MAHI FILLETS$2 off WC FillCalifornia Harvest1.08 Ib @ 1.99 /IbUTTARE =PLUMS BLACK CV 2.ITEM =NHP SLICED OVEN RONHP SLICED HICKORY1°64) The eo2e71b TARE 01UT GALA APPLES OG 3.26 BITEM = 94135 45.44 '),
#  ('Test3893.jpg',
#   "“Hf you're not out and proud, you'remissing out on the best month ofthe year. Don't spend another yearhiding in a closet of fear and shameYou don't have forever, you deserve“er and your tribe is waiting towelcome you home.’ "),
#  ('Test2280.jpg', ' '),
#  ('Test2959.jpg', 'Lil Swh telLadCeriseesCee '),
#  ('Test128.jpg', ' '),
#  ('5.jpg',
#   'WHOLE FOODsMARKETsunnyvale SVL 408-419-1290150 E Mc Kinley Ave1 Sunnyvale, CA 94086‘ IL. SEA SALT POT CHP $1.29 Feee BRIOCHE $6.99 FCHEF PLATE MEAL $10. 3 $10.00 ea $20.00 Fsubtotal  $28.28Net Sales $28.26Total $28 .28Sold Items 4PaidRETURNS We are now accepting returns onpurchases with the following conditionsReturns will only be accepted on purchasesmade on or after 9/15/2020. All returnsrequire a receipt. No returns on itemspurchased after 90 days. For additionalinformation please visit wfm.com/returns.KRKK KKK KKK KKK RK KKK KK KK KEK RK KK KK KKK KRRKEREarn 5% Back at Whole Foods Marketwith the Amazon Prime Rewards Visa.Learn more at amazon.com/amazonvisaKEK KK KR KK RRR KKK IKOK KK KKK RAK AKHOW WAS YOUR SHOPPING EXPERIENCE?Go to htto//www.wfm.com/feedbackENTER FOR A CHANCE TO WIN A $250 GIFT CARD908 6387 02/10/2021 0710 PMAMT63011070790806387021020210pev6ecd Thanke fa~ ae '),
#  ('Test158.jpg', ' '),
#  ('Test144.jpg', ' '),
#  ('Test218.jpg', ' '),
#  ('Test993.jpg',
#   'Being gay is not a crimeand it is not a sin. Stop usingGod to justify your prejudice.Nee erelee lim eu ieme gsFU mM CUM Cey mee isdse) elie Cem CO 1K)ee Being Gay & Proud Quoteswww. geckoandfly.comi ——_ '),
#  ('Test3118.jpg', 'A KEEP CALMAND LOVEWHO YOU WANTior '),
#  ('Test761.jpg', "CPehieveyou canyou're halfwayT. ROOSEVELT "),
#  ('Test614.jpg',
#   '| learnedcompassion frombeing discriminatedagainst. Everythingbad that’s everhappened tome has taughtme compassion.ELCENIDEGENERES '),
#  ('9.jpg',
#   'Yol antecashier9/08/14TK FP 20148200000TK FP 3014820000030000020324497921020159001340144700019037055280303B/BESTBAR S MEAT FRNK0/M HAMWINCO NOODLES20 .84TNDRBRD CHIX BR 3797101318KRFT DELUXE MAC 21000658862@ 1.82EGGO WAFFLE — 9800037435L/D NUTTY BARS 2430004120L\\D OATMEAL CRM 2430004101LINKS MILD 74295503660KEEB TOWNHOUSE 3010010055TURKEY FRANK 4222281210RESERS POT SLD 7111719300DM SPAG SAl 2400052363HUNTS MANHICH 27000442122 3220 «8.OM PNAPL CHNKY 240000016.TI | WT 7055200WINCO HOMO MILK Foss240000EGas 7003837280SUBTOTALTOTAL TAX '),
#  ('Test2209.jpg', 'elolebaaitieebabeed actedbee oreldpieehierserltena '),
#  ('Test1644.jpg', ' ELAINA '),
#  ('Test165.jpg', ' '),
#  ('Test1954.jpg', ' '),
#  ('Test1122.jpg',
#   '‘Zeigler, author of "Fair Play How LGBT Athletes are Claiming theirRightful Place in Sports.” defied the motion that sports are inberemtyhomophobic. Part of what is keeping gay athletes closeted, Zeigher said, iythe hyper heteromeninm that exists in locket roams. Negative talk aboutbay people isnot the iste. Instead, i\'s the demeaning talk about women, '),
#  ('Test228.jpg', ' '),
#  ('Test162.jpg', ' '),
#  ('Test113.jpg', ' '),
#  ('Test757.jpg', 'a.er)PocaPr ete)Poca)happened toDeerCeti '),
#  ('Test3360.jpg', 'CeesaPoe eee eesrooLae '),
#  ('Test3294.jpg', ' '),
#  ('Test2424.jpg', " La not dfva'd oaWO. Tan "),
#  ('Test1012.jpg', ' eSocd) |aie alLR '),
#  ('Test231.jpg', ' '),
#  ('Test533.jpg', ' '),
#  ('Test612.jpg', 'BEYrurget-- '),
#  ('Test179.jpg',
#   'cee et eo my ie te any ee oees et neo(nt my 2 pf ng thn De ye yh ee '),
#  ('Test360.jpg', ' '),
#  ('Test107.jpg',
#   'lesbianvenomlesbianvenomstraighteners aren’t worth ur money i’ve been using one for threeweeks and i’m still definitely a lesbianin all my 20 years of living this has been by far my best joke ever '),
#  ('Test125.jpg',
#   "BITCHGHETTO __ILLEGAL ALIENNO HOMORETARDED & LAMETHAT'S SO GAYWHORE/HO & SLUT "),
#  ('Test665.jpg',
#   " ’=What is straight? Ass gine can be straight,< ~ A ora street, but thehuman heart, oh, no, \\. dt's curved likearoad throughmountains. Qsayingimages.com\\ TENNESSEEWILLIAMS "),
#  ('Test779.jpg', 'We are legal" In all fifty states"\' '),
#  ('Test103.jpg', ' '),
#  ('Test1271.jpg',
#   ' A MARRIAGE HASALWAYS BEEN,BETWEEN A MANAND A WOMAN.»Re ora0) — '),
#  ('Test760.jpg', 'wedstand wp andstart te fight '),
#  ('Test579.jpg', "Life's a game. Play to win. "),
#  ('Test1001.jpg',
#   "When people askwhat I see in you,I just smile andlook away becauseI'm afraid if they knew,they'd fall in lovewith you too. "),
#  ('Test176.jpg', ' '),
#  ('Test353.jpg', ' '),
#  ('10.jpg', 'ThankPleYouetainppingipJith Us )r Bergyille '),
#  ('Test131.jpg', ' '),
#  ('Test140.jpg', ' '),
#  ('Test489.jpg', 'NE ea stUa ry4i a dePe '),
#  ('Test201.jpg', ' '),
#  ('Test237.jpg', ' ')]

# %%
dfImages = pd.DataFrame(lstImage_text)

# %%
dfImages
# Out:
#                 0                                                  1
# 0     Test250.jpg                                    WWW.GDBLOG.NET
# 1     Test230.jpg                               Top Pro & ConQuotes
# 2    Test3159.jpg                                                 4
# 3    Test2870.jpg   Woe) ee the stem ELL) eel eean alien from out...
# 4    Test1717.jpg                                  1009 MIE“of aCag
# ..            ...                                                ...
# 254   Test131.jpg
# 255   Test140.jpg
# 256   Test489.jpg                            NE ea stUa ry4i a dePe
# 257   Test201.jpg
# 258   Test237.jpg
#
# [259 rows x 2 columns]

# %%
dfImages.to_csv("images_to_txt.csv")
